# %% [markdown]
# ## Background

# %% [markdown]
# ### Current dataset (if exists)
#
# PROBA-V is not currently in our RS data list.

# %% [markdown]
# ### Need for a new data product
#
# #### New dataset description
#
# The [PROBA-V](https://www.vito-eodata.be/PDF/image/PROBAV-Products_User_Manual.pdf) satellite was launched on 6 May 2013 and flies at an altitude of 820 km in a sun-synchronous orbit with a local overpass time at launch of 10:45 h. The VEGETATION instrument aboard PROBA-V has a Field Of View of 102°, resulting in a swath width of 2295 km. This swath width ensures a daily near-global coverage (90%), whereas the full global coverage is achieved every 2 days. The central camera observes at 100 m nominal resolution, which
# covers a swath of about 517 km that ensures global coverage every 5 days. PROBA-V observes in four spectral bands: BLUE (centered at 0.463 µm), RED (0.655 µm), NIR (0.837µm), and SWIR (1.603 µm).
#
# Compared to Landsat-8 (16-day repeat cycle) and Sentinel-2 (10-day repeat cycle), PROBA-V has a better temporal coverage with some sacrifice in spatial resolution (finest-resolution product is at 100m). However, it is worth noting that the data [harmonization activity](https://www.mdpi.com/1424-8220/20/22/6631/htm) of Landsat and Sentinel has reduced the revisit time to 2.3 days, and may be a finer-resolution alternative, especially for the period of June, 2020 onwards when PROBA-V mission [ended operations](https://earth.esa.int/eogateway/news/new-experimental-phase-for-proba-v)

# %% [markdown]
# #### Literature research about new data
#
# For the ingestion of PROBA-V, we review the current caveats of existing data and propose the following changes:
#
# * We use the top-of-canopy (TOC) product and select 3 surface reflectance bands (`Red, NIR, SWIR`) and the `NDVI` band as the derived feature. We do not include the `Blue` band, which is more sensitive to atmospheric effect and can be more noisy (e.g. the landsat validation of [non-forest biomes in China](https://www.mdpi.com/2072-4292/14/1/83/htm) and [forest/non-forest biomes in the US](https://www.mdpi.com/2072-4292/11/13/1543)).
#
# * We use the QA flags (`SM` band) in PROBA-V to remove cloud issues. The [cloud and shadow detections](https://www.vito-eodata.be/PDF/image/PROBAV-Products_User_Manual.pdf) in PROBA-V were from a machine-learning approach (cloud) and radiometric/geometric approach. In addition, we try additional filters including SZA and VZA conditions, which is recommended in the same [product manual]((https://www.vito-eodata.be/PDF/image/PROBAV-Products_User_Manual.pdf)) for choosing good quality data.
#
# * The seasonality features are not considered for now, similar to our Landsat case, but will be investigated at a later stage.

# %% [markdown]
# #### Evidences of new data used in biomass studies
#
# This section is to provide evidences in existing literature/projects that the use of proposed data set can improve the biomass estimation. For PROBA-V TOC data set, it is used in vegetation studies, e.g. as the main data source for the Copernicus Global Land Services [(CGLS) Land Cover product](https://land.copernicus.eu/global/products/lc), and the more recent global [forest management data](https://www.nature.com/articles/s41597-022-01332-3).

# %% [markdown]
# ## Methodology (Processing steps)
#
# This section is mainly to provide code examples of proposed data ingestion. Main steps include
#
# * Working environment setup
#
# * Raw PROBA-V (TOC product without QA)
#
# * PROBA-V TOC with different QA filters

# %% [markdown]
# ### Setting up environment

# %%
#!pip install geemap

# %%
import ee
import geemap.foliumap as geemap
from geemap import colormaps
from functools import partial

# %%
# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize()

# %%
#functions
def gain_offset_sr(image):
    image = image.multiply(0.0005).add(0)
    return image


def gain_offset_vi(image):
    image = image.multiply(0.004).add(-0.08)
    return image


#parameters
param_vis = {
    'min': 0,
    'max': 0.5,
    'bands': ["SWIR", "NIR", "RED"]
}
ndvi_vis = {
    'min': 0,
    'max': 1,
    'palette': ['black','red', 'orange', 'yellow', 'green'],
    'bands': ["NDVI",]
}
count_vis = {
    'min': 0,
    'max': 100,
    'bands': ["NIR_count",]
}

# %% [markdown]
# ### PROBA-V Raw

# %%
# time range
year = 2019
start_date = ee.Date.fromYMD(year, 1, 1)
end_date = ee.Date.fromYMD(year, 12, 31)


# image collection
bands = ["RED", "NIR", "SWIR", "NDVI"]
filtered = (
    ee.ImageCollection('VITO/PROBAV/C1/S1_TOC_100M')
        .filterDate(start_date, end_date)
        .select(bands)
)

# feature extraction
features = filtered.median()

# normalization
sr = gain_offset_sr(features.select(bands[:3]))
vi = gain_offset_vi(features.select(bands[3:4]))
out_features = sr.addBands(vi)   # Main Output bands
print(out_features.getInfo())

count = filtered.reduce(ee.Reducer.count()) # for visual check
print(count.bandNames().getInfo())

# visualization
Map = geemap.Map(center=(-5, -50), zoom=6)
Map.addLayer(count, count_vis, 'count')
Map.addLayer(out_features, ndvi_vis, 'ndvi')
Map.addLayer(out_features, param_vis, 'PROBA-V')

Map
# Out:
# {'type': 'Image', 'bands': [{'id': 'RED', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -16.384, 'max': 16.3835}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'NIR', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -16.384, 'max': 16.3835}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'SWIR', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -16.384, 'max': 16.3835}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'NDVI', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -0.08, 'max': 0.9400000000000001}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}]}
# ['RED_count', 'NIR_count', 'SWIR_count', 'NDVI_count']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9284b28eb6fd86d5645e03922123882c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9284b28eb6fd86d5645e03922123882c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9284b28eb6fd86d5645e03922123882c = L.map(
#                 &quot;map_9284b28eb6fd86d5645e03922123882c&quot;,
#                 {
#                     center: [-5.0, -50.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     pluginLayercontrol: false,
#                     locateControl: false,
#                     searchControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_062d52a8be04bc01932f05ebb9146b0e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9284b28eb6fd86d5645e03922123882c);
#
#
#             var tile_layer_7d5f63b88d6883f4308cb1381044328f = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9284b28eb6fd86d5645e03922123882c);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_9284b28eb6fd86d5645e03922123882c);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_9284b28eb6fd86d5645e03922123882c
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_af93e2ea76238696ff1ccc71d2280903 = new L.Control.Draw(
#                 options
#             ).addTo( map_9284b28eb6fd86d5645e03922123882c );
#             map_9284b28eb6fd86d5645e03922123882c.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_9284b28eb6fd86d5645e03922123882c.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_9284b28eb6fd86d5645e03922123882c.setView(e.geocode.center, 11);
#             }).addTo(map_9284b28eb6fd86d5645e03922123882c);
#
#
#
#             map_9284b28eb6fd86d5645e03922123882c.fitBounds(
#                 [[-5, -50], [-5, -50]],
#                 {&quot;maxZoom&quot;: 6}
#             );
#
#
#             var tile_layer_3d0a11eca80a04651e9d09a9532e123d = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/ff53c193abc649bbe3cc99824ed7cc19-9619a769a21fede30256c8453f79495c/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap

# %% [markdown]
# ### PROBA-V Filtered

# %% [markdown]
# #### Cloud/Ice masking, Annual median composites

# %%
# masking
def maskClouds(image):
    flag1 = ee.Number(127);  # binary: 01111111

    img = image.updateMask(
      image.select(["SM"]).bitwiseAnd(flag1).eq(120)   # binary: 01111000
    )
    return img


# time range
year = 2019
start_date = ee.Date.fromYMD(year, 1, 1)
end_date = ee.Date.fromYMD(year, 12, 31)


# image collection
bands = ["RED", "NIR", "SWIR", "NDVI"]
filtered = (
    ee.ImageCollection('VITO/PROBAV/C1/S1_TOC_100M')
        .filterDate(start_date, end_date)
        .map(maskClouds)
        .select(bands)
)

# feature extraction
features = filtered.median()

# normalization
sr = gain_offset_sr(features.select(bands[:3]))
vi = gain_offset_vi(features.select(bands[3:4]))
out_features = sr.addBands(vi)   # Main Output bands
print(out_features.getInfo())

count = filtered.reduce(ee.Reducer.count()) # for visual check
print(count.bandNames().getInfo())

# visualization
Map = geemap.Map(center=(-5, -50), zoom=6)
Map.addLayer(count, count_vis, 'count')
Map.addLayer(out_features, ndvi_vis, 'ndvi')
Map.addLayer(out_features, param_vis, 'PROBA-V')

Map
# Out:
# {'type': 'Image', 'bands': [{'id': 'RED', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -16.384, 'max': 16.3835}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'NIR', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -16.384, 'max': 16.3835}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'SWIR', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -16.384, 'max': 16.3835}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'NDVI', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -0.08, 'max': 0.9400000000000001}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}]}
# ['RED_count', 'NIR_count', 'SWIR_count', 'NDVI_count']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a520265a68e0dee5ba9a962ab0390ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a520265a68e0dee5ba9a962ab0390ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3a520265a68e0dee5ba9a962ab0390ee = L.map(
#                 &quot;map_3a520265a68e0dee5ba9a962ab0390ee&quot;,
#                 {
#                     center: [-5.0, -50.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     pluginLayercontrol: false,
#                     locateControl: false,
#                     searchControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03fa415e3ebc676d01a0865524e22a91 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3a520265a68e0dee5ba9a962ab0390ee);
#
#
#             var tile_layer_7d5f63b88d6883f4308cb1381044328f = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3a520265a68e0dee5ba9a962ab0390ee);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_3a520265a68e0dee5ba9a962ab0390ee);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_3a520265a68e0dee5ba9a962ab0390ee
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_e30b5aa36a67b6613505cf3aa488c88e = new L.Control.Draw(
#                 options
#             ).addTo( map_3a520265a68e0dee5ba9a962ab0390ee );
#             map_3a520265a68e0dee5ba9a962ab0390ee.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_3a520265a68e0dee5ba9a962ab0390ee.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_3a520265a68e0dee5ba9a962ab0390ee.setView(e.geocode.center, 11);
#             }).addTo(map_3a520265a68e0dee5ba9a962ab0390ee);
#
#
#
#             map_3a520265a68e0dee5ba9a962ab0390ee.fitBounds(
#                 [[-5, -50], [-5, -50]],
#                 {&quot;maxZoom&quot;: 6}
#             );
#
#
#             var tile_layer_022f5db2b8b9b7d5958875991c9e1f19 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/f2fb8590e48e26b387bcbc26548d4e51-51f132aaa2ee776ad90e30c3a7366871/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap

# %% [markdown]
# #### More QA masking, Annual median composites

# %%
# masking
def maskClouds(image):
    flag1 = ee.Number(127);  # binary: 01111111

    img = image.updateMask(
      image.select(["SM"]).bitwiseAnd(flag1).eq(120)   # binary: 01111000
      .And(image.select(["NIR"]).gte(0))
      .And(image.select(["NDVI"]).lt(255))
      .And(image.select(["SZA"]).lt(120))   # scaling x2
      .And(image.select(["VNIRVZA"]).lt(120))   # scaling x2
    )
    return img


# time range
year = 2019
start_date = ee.Date.fromYMD(year, 1, 1)
end_date = ee.Date.fromYMD(year, 12, 31)


# image collection
bands = ["RED", "NIR", "SWIR", "NDVI"]
filtered = (
    ee.ImageCollection('VITO/PROBAV/C1/S1_TOC_100M')
        .filterDate(start_date, end_date)
        .map(maskClouds)
        .select(bands)
)

# feature extraction
features = filtered.median()

# normalization
sr = gain_offset_sr(features.select(bands[:3]))
vi = gain_offset_vi(features.select(bands[3:4]))
out_features = sr.addBands(vi)   # Main Output bands
print(out_features.getInfo())

count = filtered.reduce(ee.Reducer.count()) # for visual check
print(count.bandNames().getInfo())

# visualization
Map = geemap.Map(center=(-5, -50), zoom=6)
Map.addLayer(count, count_vis, 'count')
Map.addLayer(out_features, ndvi_vis, 'ndvi')
Map.addLayer(out_features, param_vis, 'PROBA-V')

Map
# Out:
# {'type': 'Image', 'bands': [{'id': 'RED', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -16.384, 'max': 16.3835}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'NIR', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -16.384, 'max': 16.3835}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'SWIR', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -16.384, 'max': 16.3835}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'NDVI', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -0.08, 'max': 0.9400000000000001}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}]}
# ['RED_count', 'NIR_count', 'SWIR_count', 'NDVI_count']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42a3b03919198d233ca7c21433bc1764 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42a3b03919198d233ca7c21433bc1764&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_42a3b03919198d233ca7c21433bc1764 = L.map(
#                 &quot;map_42a3b03919198d233ca7c21433bc1764&quot;,
#                 {
#                     center: [-5.0, -50.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     pluginLayercontrol: false,
#                     locateControl: false,
#                     searchControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_169c1ef7034fa3bd98ae04e86f0490d6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_42a3b03919198d233ca7c21433bc1764);
#
#
#             var tile_layer_7d5f63b88d6883f4308cb1381044328f = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_42a3b03919198d233ca7c21433bc1764);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_42a3b03919198d233ca7c21433bc1764);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_42a3b03919198d233ca7c21433bc1764
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_8584ceca73736c163a84465cde340a95 = new L.Control.Draw(
#                 options
#             ).addTo( map_42a3b03919198d233ca7c21433bc1764 );
#             map_42a3b03919198d233ca7c21433bc1764.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_42a3b03919198d233ca7c21433bc1764.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_42a3b03919198d233ca7c21433bc1764.setView(e.geocode.center, 11);
#             }).addTo(map_42a3b03919198d233ca7c21433bc1764);
#
#
#
#             map_42a3b03919198d233ca7c21433bc1764.fitBounds(
#                 [[-5, -50], [-5, -50]],
#                 {&quot;maxZoom&quot;: 6}
#             );
#
#
#             var tile_layer_f1132a25942656db73205a966ae5f232 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/c3b6c3a0d89e1b5d1dcff76f03236f52-9792cb876e0ccb2e11b2cbe5998f1b04/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap

# %% [markdown]
# #### More QA masking, max ndvi composites

# %%
# masking
def maskClouds(image):
    flag1 = ee.Number(127);  # binary: 01111111

    img = image.updateMask(
      image.select(["SM"]).bitwiseAnd(flag1).eq(120)   # binary: 01111000
      .And(image.select(["NIR"]).gte(0))
      .And(image.select(["NDVI"]).lt(255))
      .And(image.select(["SZA"]).lt(120))   # scaling x2
      .And(image.select(["VNIRVZA"]).lt(120))   # scaling x2
    )
    return img


# time range
year = 2019
start_date = ee.Date.fromYMD(year, 1, 1)
end_date = ee.Date.fromYMD(year, 12, 31)


# image collection
bands = ["RED", "NIR", "SWIR", "NDVI"]
filtered = (
    ee.ImageCollection('VITO/PROBAV/C1/S1_TOC_100M')
        .filterDate(start_date, end_date)
        .map(maskClouds)
        .select(bands)
)

# feature extraction
features = filtered.qualityMosaic('NDVI')

# normalization
sr = gain_offset_sr(features.select(bands[:3]))
vi = gain_offset_vi(features.select(bands[3:4]))
out_features = sr.addBands(vi)   # Main Output bands
print(out_features.getInfo())

count = filtered.reduce(ee.Reducer.count()) # for visual check
print(count.bandNames().getInfo())

# visualization
Map = geemap.Map(center=(-5, -50), zoom=6)
Map.addLayer(count, count_vis, 'count')
Map.addLayer(out_features, ndvi_vis, 'ndvi')
Map.addLayer(out_features, param_vis, 'PROBA-V')

Map
# Out:
# {'type': 'Image', 'bands': [{'id': 'RED', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -16.384, 'max': 16.3835}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'NIR', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -16.384, 'max': 16.3835}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'SWIR', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -16.384, 'max': 16.3835}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'NDVI', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -0.08, 'max': 0.9400000000000001}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}]}
# ['RED_count', 'NIR_count', 'SWIR_count', 'NDVI_count']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9097f5be1b62dccc90b2080f90ac3063 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9097f5be1b62dccc90b2080f90ac3063&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9097f5be1b62dccc90b2080f90ac3063 = L.map(
#                 &quot;map_9097f5be1b62dccc90b2080f90ac3063&quot;,
#                 {
#                     center: [-5.0, -50.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     pluginLayercontrol: false,
#                     locateControl: false,
#                     searchControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a06608b21b2ebb006e93f27d573a3602 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9097f5be1b62dccc90b2080f90ac3063);
#
#
#             var tile_layer_7d5f63b88d6883f4308cb1381044328f = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9097f5be1b62dccc90b2080f90ac3063);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_9097f5be1b62dccc90b2080f90ac3063);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_9097f5be1b62dccc90b2080f90ac3063
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_89fa1b3f0ce57bb66860476c7d2203e7 = new L.Control.Draw(
#                 options
#             ).addTo( map_9097f5be1b62dccc90b2080f90ac3063 );
#             map_9097f5be1b62dccc90b2080f90ac3063.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_9097f5be1b62dccc90b2080f90ac3063.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_9097f5be1b62dccc90b2080f90ac3063.setView(e.geocode.center, 11);
#             }).addTo(map_9097f5be1b62dccc90b2080f90ac3063);
#
#
#
#             map_9097f5be1b62dccc90b2080f90ac3063.fitBounds(
#                 [[-5, -50], [-5, -50]],
#                 {&quot;maxZoom&quot;: 6}
#             );
#
#
#             var tile_layer_5d5805c18301a307b98b80d654abf65c = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/c3b6c3a0d89e1b5d1dcff76f03236f52-47919fd2e1eceb0bf0d44a539ced0bcc/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap

# %% [markdown]
# ####More QA Masking, ndvi thresholding, interval median

# %%
# masking
def maskClouds(image):
    flag1 = ee.Number(127);  # binary: 01111111

    img = image.updateMask(
      image.select(["SM"]).bitwiseAnd(flag1).eq(120)   # binary: 01111000
      .And(image.select(["NIR"]).gte(0))
      .And(image.select(["NDVI"]).lt(255))
      .And(image.select(["SZA"]).lt(120))   # scaling x2
      .And(image.select(["VNIRVZA"]).lt(120))   # scaling x2
    )
    return img


def maskNDVI(image, med_ndvi):
    img = image.updateMask(
        image.select(['NDVI']).gte(med_ndvi)
    )
    return img


# time range
year = 2019
start_date = ee.Date.fromYMD(year, 1, 1)
end_date = ee.Date.fromYMD(year, 12, 31)


# image collection
bands = ["RED", "NIR", "SWIR", "NDVI"]
filtered = (
    ee.ImageCollection('VITO/PROBAV/C1/S1_TOC_100M')
        .filterDate(start_date, end_date)
        .map(maskClouds)
        .select(bands)
)

# feature extraction
med_ndvi = filtered.median().select(['NDVI'])
maskNDVI_med = partial(maskNDVI, med_ndvi=med_ndvi)
features = filtered.map(maskNDVI_med).median()


# normalization
sr = gain_offset_sr(features.select(bands[:3]))
vi = gain_offset_vi(features.select(bands[3:4]))
out_features = sr.addBands(vi)   # Main Output bands
print(out_features.getInfo())

count = filtered.reduce(ee.Reducer.count()) # for visual check
print(count.bandNames().getInfo())

# visualization
Map = geemap.Map(center=(-5, -50), zoom=6)
Map.addLayer(count, count_vis, 'count')
Map.addLayer(out_features, ndvi_vis, 'ndvi')
Map.addLayer(out_features, param_vis, 'PROBA-V')

Map
# Out:
# {'type': 'Image', 'bands': [{'id': 'RED', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -16.384, 'max': 16.3835}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'NIR', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -16.384, 'max': 16.3835}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'SWIR', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -16.384, 'max': 16.3835}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'NDVI', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -0.08, 'max': 0.9400000000000001}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}]}
# ['RED_count', 'NIR_count', 'SWIR_count', 'NDVI_count']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52509b8accfe3db5497e9a12a375ecb0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52509b8accfe3db5497e9a12a375ecb0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_52509b8accfe3db5497e9a12a375ecb0 = L.map(
#                 &quot;map_52509b8accfe3db5497e9a12a375ecb0&quot;,
#                 {
#                     center: [-5.0, -50.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     pluginLayercontrol: false,
#                     locateControl: false,
#                     searchControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08d5c039fabf68d26d8d3ad49a435fbb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_52509b8accfe3db5497e9a12a375ecb0);
#
#
#             var tile_layer_7d5f63b88d6883f4308cb1381044328f = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_52509b8accfe3db5497e9a12a375ecb0);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_52509b8accfe3db5497e9a12a375ecb0);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_52509b8accfe3db5497e9a12a375ecb0
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_431ff7505f0df30063e8ecdd1d614137 = new L.Control.Draw(
#                 options
#             ).addTo( map_52509b8accfe3db5497e9a12a375ecb0 );
#             map_52509b8accfe3db5497e9a12a375ecb0.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_52509b8accfe3db5497e9a12a375ecb0.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_52509b8accfe3db5497e9a12a375ecb0.setView(e.geocode.center, 11);
#             }).addTo(map_52509b8accfe3db5497e9a12a375ecb0);
#
#
#
#             map_52509b8accfe3db5497e9a12a375ecb0.fitBounds(
#                 [[-5, -50], [-5, -50]],
#                 {&quot;maxZoom&quot;: 6}
#             );
#
#
#             var tile_layer_9be505d82276eb8278af68062637ccf3 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/c3b6c3a0d89e1b5d1dcff76f03236f52-6183135c9f1a90dba4d5633366e97b03/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap
